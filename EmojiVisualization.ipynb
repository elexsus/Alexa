# %% [markdown]
# <a href="https://colab.research.google.com/github/elexsus/Alexa/blob/main/EmojiVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path='/content/emoji.csv'
emoji_data=pd.read_csv(path)
emoji_data.head()
# Out:
#    Unnamed: 0 emoji  ... codepoints Popularity
# 0           0     😀  ...      1F600         98
# 1           1     😃  ...      1F603         74
# 2           2     😄  ...      1F604         74
# 3           3     😁  ...      1F601         54
# 4           4     😆  ...      1F606         95
#
# [5 rows x 7 columns]

# %%
emoji_data.tail()
# Out:
#       Unnamed: 0  ... Popularity
# 4154        4154  ...         19
# 4155        4155  ...         22
# 4156        4156  ...         89
# 4157        4157  ...         23
# 4158        4158  ...         82
#
# [5 rows x 7 columns]

# %%
emoji_data['group'].value_counts().plot.pie(figsize=(10,8))  
# show plot 
plt.show()

# %%
emoji_objects=emoji_data[emoji_data.group=='Objects']
emoji_objects['sub_group'].value_counts().plot.pie(figsize=(10,8))  
# show plot 
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.countplot('group',data=emoji_data)
plt.show()

# %%
plt.figure(figsize=(16,10))
emoji_animal=emoji_data[emoji_data.group=='Animals & Nature']
sns.countplot('sub_group',data=emoji_animal)
plt.show()
